# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib notebook

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

import build_features

# %%
def obs2mat(o):
    side = 90
    A = np.zeros((side, side), dtype=np.float64)
    A[np.tril_indices(side)] = o
    A = A + A.T
    A[np.diag_indices(side)] /= 2.0
    return A

def plot_mat(m, ax=None):
    if ax is None:
        fig, ax = plt.subplots()
    ax.imshow(obs2mat(s01X[0,:,3]), vmin=0, vmax=1, interpolation="none", aspect="equal", cmap="inferno")
    ax.grid(False)
    ax.set_xticklabels([])
    ax.set_yticklabels([])
    return ax

# %%
### Load a subset of the data

# %%
s01X, s01Y = build_features.prepare_X("S01")
# Out:
# Loading subject S01
# Loaded 824 observations of shape (824, 4095, 50) in 17.86s.

# %%
fig, ax = plt.subplots()
ax.plot(s01Y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
print("Min: %f - Max: %f - Mean: %f - Std: %f - Median: %f" % 
      (np.amin(s01X), np.amax(s01X), np.mean(s01X), np.std(s01X), np.median(s01X)))
means = []; medians = []; maxs = []; mins = []; stds = []
for freq in range(s01X.shape[2]):
    print("Freq %d Hz:" % (freq + 1))
    means.append(np.mean(s01X[:,:,freq]))
    medians.append(np.median(s01X[:,:,freq]))
    maxs.append(np.amax(s01X[:,:,freq]))
    mins.append(np.amin(s01X[:,:,freq]))
    stds.append(np.std(s01X[:,:,freq]))
    print("\t Min: %f - Max: %f - Mean: %f - Std: %f - Median: %f" % 
      (mins[-1], maxs[-1], means[-1], 
       stds[-1], medians[-1]))
means = np.asarray(means)
medians = np.asarray(medians)
maxs = np.asarray(maxs)
mins = np.asarray(mins)
stds = np.asarray(stds)
# Out:
# Min: 0.000000 - Max: 0.958619 - Mean: 0.148317 - Std: 0.148108 - Median: 0.104590
# Freq 1 Hz:
# 	 Min: 0.000000 - Max: 0.919626 - Mean: 0.123461 - Std: 0.120694 - Median: 0.087428
# Freq 2 Hz:
# 	 Min: 0.000000 - Max: 0.958619 - Mean: 0.176304 - Std: 0.152969 - Median: 0.139997
# Freq 3 Hz:
# 	 Min: 0.000000 - Max: 0.927390 - Mean: 0.171510 - Std: 0.150086 - Median: 0.136237
# Freq 4 Hz:
# 	 Min: 0.000000 - Max: 0.908110 - Mean: 0.165592 - Std: 0.146713 - Median: 0.130054
# Freq 5 Hz:
# 	 Min: 0.000000 - Max: 0.911918 - Mean: 0.162507 - Std: 0.145735 - Median: 0.126460
# Freq 6 Hz:
# 	 Min: 0.000000 - Max: 0.903926 - Mean: 0.161817 - Std: 0.145198 - Median: 0.126621
# Freq 7 Hz:
# 	 Min: 0.000000 - Max: 0.889265 - Mean: 0.164580 - Std: 0.148373 - Median: 0.128071
# Freq 8 Hz:
# 	 Min: 0.000000 - Max: 0.925632 - Mean: 0.163173 - Std: 0.149575 - Median: 0.125030
# Freq 9 Hz:
# 	 Min: 0.000000 - Max: 0.893519 - Mean: 0.162434 - Std: 0.149660 - Median: 0.123766
# Freq 10 Hz:
# 	 Min: 0.000000 - Max: 0.900943 - Mean: 0.162351 - Std: 0.148946 - Median: 0.124611
# Freq 11 Hz:
# 	 Min: 0.000000 - Max: 0.932908 - Mean: 0.160925 - Std: 0.148564 - Median: 0.123013
# Freq 12 Hz:
# 	 Min: 0.000000 - Max: 0.905966 - Mean: 0.163232 - Std: 0.150055 - Median: 0.125523
# Freq 13 Hz:
# 	 Min: -0.000000 - Max: 0.907193 - Mean: 0.172713 - Std: 0.156077 - Median: 0.135193
# Freq 14 Hz:
# 	 Min: 0.000000 - Max: 0.892644 - Mean: 0.169050 - Std: 0.152572 - Median: 0.132581
# Freq 15 Hz:
# 	 Min: -0.000000 - Max: 0.911170 - Mean: 0.160416 - Std: 0.149143 - Median: 0.122020
# Freq 16 Hz:
# 	 Min: 0.000000 - Max: 0.888721 - Mean: 0.152076 - Std: 0.145285 - Median: 0.112608
# Freq 17 Hz:
# 	 Min: -0.000000 - Max: 0.876297 - Mean: 0.149250 - Std: 0.145350 - Median: 0.108157
# Freq 18 Hz:
# 	 Min: 0.000000 - Max: 0.867495 - Mean: 0.147720 - Std: 0.144549 - Median: 0.106556
# Freq 19 Hz:
# 	 Min: 0.000000 - Max: 0.880844 - Mean: 0.149049 - Std: 0.145981 - Median: 0.107535
# Freq 20 Hz:
# 	 Min: 0.000000 - Max: 0.932426 - Mean: 0.147417 - Std: 0.145310 - Median: 0.105518
# Freq 21 Hz:
# 	 Min: -0.000000 - Max: 0.927984 - Mean: 0.148955 - Std: 0.146295 - Median: 0.107261
# Freq 22 Hz:
# 	 Min: -0.000000 - Max: 0.878682 - Mean: 0.146727 - Std: 0.145732 - Median: 0.104224
# Freq 23 Hz:
# 	 Min: 0.000000 - Max: 0.896201 - Mean: 0.146762 - Std: 0.146284 - Median: 0.103944
# Freq 24 Hz:
# 	 Min: 0.000000 - Max: 0.894023 - Mean: 0.145710 - Std: 0.145736 - Median: 0.102519
# Freq 25 Hz:
# 	 Min: 0.000000 - Max: 0.910612 - Mean: 0.146404 - Std: 0.146100 - Median: 0.103495
# Freq 26 Hz:
# 	 Min: 0.000000 - Max: 0.891999 - Mean: 0.142425 - Std: 0.144397 - Median: 0.098705
# Freq 27 Hz:
# 	 Min: 0.000000 - Max: 0.925820 - Mean: 0.142205 - Std: 0.145944 - Median: 0.096604
# Freq 28 Hz:
# 	 Min: -0.000000 - Max: 0.891829 - Mean: 0.141366 - Std: 0.145849 - Median: 0.095076
# Freq 29 Hz:
# 	 Min: 0.000000 - Max: 0.896893 - Mean: 0.141795 - Std: 0.146806 - Median: 0.095152
# Freq 30 Hz:
# 	 Min: 0.000000 - Max: 0.913571 - Mean: 0.140487 - Std: 0.146389 - Median: 0.093213
# Freq 31 Hz:
# 	 Min: 0.000000 - Max: 0.907034 - Mean: 0.141595 - Std: 0.147479 - Median: 0.094151
# Freq 32 Hz:
# 	 Min: 0.000000 - Max: 0.905003 - Mean: 0.141945 - Std: 0.147885 - Median: 0.094025
# Freq 33 Hz:
# 	 Min: 0.000000 - Max: 0.897913 - Mean: 0.140655 - Std: 0.147834 - Median: 0.091946
# Freq 34 Hz:
# 	 Min: 0.000000 - Max: 0.875687 - Mean: 0.142429 - Std: 0.149563 - Median: 0.093063
# Freq 35 Hz:
# 	 Min: -0.000000 - Max: 0.880364 - Mean: 0.141226 - Std: 0.148815 - Median: 0.091827
# Freq 36 Hz:
# 	 Min: 0.000000 - Max: 0.903504 - Mean: 0.140943 - Std: 0.148687 - Median: 0.091564
# Freq 37 Hz:
# 	 Min: 0.000000 - Max: 0.907615 - Mean: 0.140671 - Std: 0.148763 - Median: 0.091111
# Freq 38 Hz:
# 	 Min: 0.000000 - Max: 0.943544 - Mean: 0.134852 - Std: 0.145653 - Median: 0.084112
# Freq 39 Hz:
# 	 Min: 0.000000 - Max: 0.884420 - Mean: 0.138955 - Std: 0.148991 - Median: 0.087515
# Freq 40 Hz:
# 	 Min: -0.000000 - Max: 0.891911 - Mean: 0.140342 - Std: 0.149719 - Median: 0.089051
# Freq 41 Hz:
# 	 Min: 0.000000 - Max: 0.905951 - Mean: 0.138528 - Std: 0.149111 - Median: 0.086543
# Freq 42 Hz:
# 	 Min: 0.000000 - Max: 0.872564 - Mean: 0.137320 - Std: 0.148620 - Median: 0.085046
# Freq 43 Hz:
# 	 Min: 0.000000 - Max: 0.919932 - Mean: 0.137512 - Std: 0.149103 - Median: 0.084479
# Freq 44 Hz:
# 	 Min: 0.000000 - Max: 0.882371 - Mean: 0.137461 - Std: 0.149241 - Median: 0.084265
# Freq 45 Hz:
# 	 Min: 0.000000 - Max: 0.893607 - Mean: 0.139349 - Std: 0.150154 - Median: 0.086615
# Freq 46 Hz:
# 	 Min: 0.000000 - Max: 0.871762 - Mean: 0.139707 - Std: 0.150449 - Median: 0.086879
# Freq 47 Hz:
# 	 Min: -0.000000 - Max: 0.926099 - Mean: 0.137531 - Std: 0.148769 - Median: 0.085126
# Freq 48 Hz:
# 	 Min: 0.000000 - Max: 0.908813 - Mean: 0.136966 - Std: 0.148728 - Median: 0.084028
# Freq 49 Hz:
# 	 Min: -0.000000 - Max: 0.935865 - Mean: 0.136412 - Std: 0.148375 - Median: 0.083291
# Freq 50 Hz:
# 	 Min: 0.000000 - Max: 0.897954 - Mean: 0.143044 - Std: 0.152000 - Median: 0.091240

# %%
print(np.sum(s01X > 0.3) / s01X.size)
# Out:
# 0.183211843712

# %%
fig, ax = plt.subplots()
for freq in range(s01X.shape[2]):
    ax.hist(s01X[:,:,freq].flatten(), label=f"{freq + 1} Hz", bins=10, alpha=0.3)
#ax.legend(loc="best")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax = plt.subplots()
ax.imshow(obs2mat(s01X[0,:,3]), vmin=0, vmax=1, interpolation="none", aspect="equal", cmap="inferno")
ax.grid(False)
ax.set_xticklabels([])
ax.set_yticklabels([])
# Out:
# <img src="data:image/png;base64,..." width="640">
# []

# %%
np.sum(obs2mat(s01X[0,:,0]) != obs2mat(s01X[0,:,0]))
# Out:
# 0
